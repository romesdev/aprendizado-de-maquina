# %% [markdown]
# # **Lista de Exercícios - 001**
#
# ### *Francisco Romes da Silva Filho, 409976*

# %% [markdown]
# ### **1. Escolha e baixe um conjunto de dados da plataforma Kaggle (https://www.kaggle.com/datasets), que tenha ao menos um atributo numérico. Carregue os dados através da biblioteca Pandas ou Dask.**

# %% [markdown]
# #### Dataset escolhido: Heart Failure Prediction (https://www.kaggle.com/andrewmvd/heart-failure-clinical-data)
# #### Breve descrição: 12 clinical features por predicting death events.

# %% [markdown]
# ### Imports

# %%
# Pandas
import pandas as pd

# %%
data_frame = pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %% [markdown]
# ### **2. Exiba as 20 primeiras linhas do conjunto de dados selecionado.**
#
# Mostrando as 20 primeiras linhas do dataset:

# %%
data_frame.head(20)
# Out:
#      age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0   75.0        0                       582         0                 20
# 1   55.0        0                      7861         0                 38
# 2   65.0        0                       146         0                 20
# 3   50.0        1                       111         0                 20
# 4   65.0        1                       160         1                 20
# 5   90.0        1                        47         0                 40
# 6   75.0        1                       246         0                 15
# 7   60.0        1                       315         1                 60
# 8   65.0        0                       157         0                 65
# 9   80.0        1                       123         0                 35
# 10  75.0        1                        81         0                 38
# 11  62.0        0                       231         0                 25
# ...

# %% [markdown]
# ### **3. Exiba o número de linhas de dados presentes no conjunto de dados selecionado.**

# %%
print ("Número de LINHAS do Dataset:{}" .format(data_frame.shape[0]))
# Out:
# Número de LINHAS do Dataset:299

# %% [markdown]
# ### **4. Exiba a média, o desvio padrão, e os valores mínimo e máximo de um campo numérico do conjunto de dados selecionado.**
#
# Atributo (campo) escolhido: "platelets"
#
# "platelets" - Platelets in the blood (kiloplatelets/mL)
#
# Significado: Nível de plaquetas no sangue

# %%
# A função 'describe()' do Pandas retorna para nós os valores que queremos.
# Média é igual a 'mean'
# Desvio Padrão é igual a 'std'
# Valor Mínimo é o valor campo 'min'
# Valor Máximo é o valor campo 'max'
# A Mediana é apresentada no campo '50%'

data_frame['platelets'].describe()
# Out:
# count       299.000000
# mean     263358.029264
# std       97804.236869
# min       25100.000000
# 25%      212500.000000
# 50%      262000.000000
# 75%      303500.000000
# max      850000.000000
# Name: platelets, dtype: float64

# %% [markdown]
# ### **5. Exiba as 5 primeiras linhas do conjunto de dados ordenado em ordem decrescente pelo mesmo campo numérico usado por você na questão 4.**

# %%
# Dataset ordenado pelo campo 'platelets' em ordem descedente. 
data_frame.sort_values(by='platelets', ascending=False)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 109  45.0        0                       292         1                 35
# 296  45.0        0                      2060         1                 60
# 105  72.0        1                       328         0                 30
# 287  45.0        0                       582         1                 55
# 240  70.0        0                        81         1                 35
# ..    ...      ...                       ...       ...                ...
# 167  59.0        0                        66         1                 20
# 230  60.0        0                       166         0                 30
# 281  70.0        0                       582         0                 40
# 15   82.0        1                       379         0                 50
# 277  70.0        0                       582         1                 38
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...
